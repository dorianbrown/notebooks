# %% [markdown]
# # Writing my first Jupyterlab notebook
#
# This seems to be pretty cool! I wonder how it will look when run.
#
# - First item
# - Second item
#
# Good, that works. Checkout this `code`.

# %%
import pandas as pd
import spacy
import re

# %% [markdown]
# ## Loading and prepping data
#
# Some other stuff we're doing

# %%
text = pd.read_csv("/home/dorian/workspace/data/shakespeare.csv", 
                   header = None, 
                   sep= ";")
text[100:150]
# Out:
#        0         1     2        3              4  \
# 100  101  Henry IV   8.0   1.1.98   WESTMORELAND
# 101  102  Henry IV   8.0   1.1.99   WESTMORELAND
# 102  103  Henry IV   9.0  1.1.100  KING HENRY IV
# 103  104  Henry IV   9.0  1.1.101  KING HENRY IV
# 104  105  Henry IV   9.0  1.1.102  KING HENRY IV
# 105  106  Henry IV   9.0  1.1.103  KING HENRY IV
# 106  107  Henry IV   9.0  1.1.104  KING HENRY IV
# 107  108  Henry IV   9.0  1.1.105  KING HENRY IV
# 108  109  Henry IV   9.0  1.1.106  KING HENRY IV
# 109  110  Henry IV   9.0  1.1.107  KING HENRY IV
# 110  111  Henry IV  10.0  1.1.108   WESTMORELAND
# 111  112  Henry IV  10.0      NaN   WESTMORELAND
# 112  113  Henry IV  10.0      NaN   WESTMORELAND
# 113  114  Henry IV  10.0      NaN   WESTMORELAND
# 114  115  Henry IV   1.0    1.2.1       FALSTAFF
# 115  116  Henry IV   2.0    1.2.2   PRINCE HENRY
# 116  117  Henry IV   2.0    1.2.3   PRINCE HENRY
# 117  118  Henry IV   2.0    1.2.4   PRINCE HENRY
# ...
